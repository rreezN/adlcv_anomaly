# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('../results/progress.csv', header=0, usecols=range(19))

# %%
df.head()
# Out:
#    grad_norm  param_norm  samples  step  train_acc@1  train_acc@1_q0  \
# 0   0.596808  103.713367    88620  8861          0.6        1.000000
# 1   1.427637  103.713696    88630  8862          0.7        1.000000
# 2   0.866614  103.713976    88640  8863          0.7        1.000000
# 3   0.984495  103.714246    88650  8864          0.9        0.833333
# 4   1.322051  103.714556    88660  8865          0.7        1.000000
#
#    train_acc@1_q1  train_acc@1_q2  train_acc@1_q3  train_acc@2  \
# 0            1.00        0.000000            0.40          1.0
# 1            0.75        0.666667            0.50          1.0
# 2            1.00        0.333333            0.75          1.0
# 3             NaN             NaN            1.00          1.0
# 4            0.00        0.000000            1.00          1.0
#
#    train_acc@2_q0  train_acc@2_q1  train_acc@2_q2  train_acc@2_q3  train_loss  \
# 0             1.0             1.0             1.0             1.0    0.624187
# 1             1.0             1.0             1.0             1.0    0.545121
# 2             1.0             1.0             1.0             1.0    0.432075
# 3             1.0             NaN             NaN             1.0    0.484414
# 4             1.0             1.0             1.0             1.0    0.504526
#
#    train_loss_q0  train_loss_q1  train_loss_q2  train_loss_q3
# 0       0.033203       0.131354       1.217320       0.939086
# 1       0.000681       0.361099       0.888800       0.669865
# 2       0.130811       0.001264       0.631773       0.573024
# 3       0.476873            NaN            NaN       0.495724
# 4       0.237271       0.791195       0.912754       0.493156

# %%
# Visualize grad_norm and param_norm columns

sns.pairplot(df[['grad_norm', 'param_norm']])
plt.show()

# %%
# Visualize samples column
plt.figure(figsize=(10, 6))
plt.plot(df['step'],df['samples'], label='samples')
plt.xlabel('Step')
plt.ylabel('Samples')
plt.title('Samples over Steps')
plt.legend()
plt.show()

# %%
# Visualize train_acc@1 and train_acc@2 columns
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['train_acc@1'], label='train_acc@1')
plt.plot(df['step'], df['train_acc@2'], label='train_acc@2')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.title('Train Accuracy over Steps')
plt.legend()
plt.show()

# %%
# Visualize train_loss column
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['train_loss'], label='train_loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Train Loss over Steps')
plt.legend()
plt.show()
