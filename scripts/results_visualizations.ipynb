# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
plt.style.use(['seaborn-v0_8','voresStyle.mplstyle'])

# %%
# Read the CSV file into a DataFrame
# read all the csv files in folder results/class_csv
for file in os.listdir("../results/class_csv"):
    if file.endswith(".csv"):
        df = pd.read_csv('../results/class_csv/' + file, header=0, usecols=range(19))
        # Plot the learning curve



df = pd.read_csv('../results/Class-2024-04-09-16-59-58-670362/progress.csv', header=0, usecols=range(19))

# %%
df.head()
# Out:
#    grad_norm  param_norm  samples  step  train_acc@1  train_acc@1_q0  \
# 0  40.342573  101.672464       10     0          0.3        1.000000
# 1  10.483426  101.672594       20     1          1.0        1.000000
# 2   3.379927  101.672966       30     2          0.7        1.000000
# 3   3.864620  101.673184       40     3          0.6        0.333333
# 4   2.826998  101.673153       50     4          0.6        0.500000
#
#    train_acc@1_q1  train_acc@1_q2  train_acc@1_q3  train_acc@2  \
# 0        0.250000        0.333333        0.000000          1.0
# 1        1.000000        1.000000        1.000000          1.0
# 2        0.666667        1.000000        0.600000          1.0
# 3        1.000000        0.666667        0.666667          1.0
# 4        1.000000        0.333333        0.666667          1.0
#
#    train_acc@2_q0  train_acc@2_q1  train_acc@2_q2  train_acc@2_q3  train_loss  \
# 0             1.0             1.0             1.0             1.0    0.704364
# ...

# %%
# Visualize grad_norm and param_norm columns

sns.pairplot(df[['grad_norm', 'param_norm']])
plt.show()

# %%
plt.figure(figsize=(8, 3))

for i, file in enumerate(os.listdir("../results/class_csv")):
    if file.endswith(".csv"):
        df = pd.read_csv('../results/class_csv/' + file, header=0, usecols=range(19))
        plt.plot(df['step'], df['train_loss'], label=f'Model {i} - MSE')
        #plt.plot(df['step'], df['mse'], label=f'Model {i} - MSE')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Classification models: Train Loss over Steps')
plt.legend()
plt.savefig('../results/class_csv/loss.pdf', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_20008\4078236722.py:12: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('../results/class_csv/loss.pdf', bbox_inches='tight')

# %%
# Visualize train_acc@1 and train_acc@2 columns
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['train_acc@1'], label='train_acc@1')
plt.plot(df['step'], df['train_acc@2'], label='train_acc@2')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.title('Train Accuracy over Steps')
plt.legend()
plt.show()

# %%
# Visualize train_loss column
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['train_loss'], label='train_loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Train Loss over Steps')
plt.legend()
plt.show()
